# %% [markdown]
# ##### Import the necessary package

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ##### Read data using pandas

# %%
df = pd.read_excel('data/online_retail_II.xlsx')
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# ##### Exploring the unique regions of dataset

# %% [markdown]
# ##### Check the number of row and col.

# %%
#check the number of columns and rows in dataframe
print("Number of rows in dataframe: ", df.shape[0])
print("**"*50)
print("Number of columns in dataframe: ", df.shape[1])
# Out:
# Number of rows in dataframe:  525461
# ****************************************************************************************************
# Number of columns in dataframe:  8

# %% [markdown]
# ##### Exploring the unique regions of dataset

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'USA', 'Belgium', 'Australia', 'EIRE',
#        'Germany', 'Portugal', 'Japan', 'Denmark', 'Nigeria',
#        'Netherlands', 'Poland', 'Spain', 'Channel Islands', 'Italy',
#        'Cyprus', 'Greece', 'Norway', 'Austria', 'Sweden',
#        'United Arab Emirates', 'Finland', 'Switzerland', 'Unspecified',
#        'Malta', 'Bahrain', 'RSA', 'Bermuda', 'Hong Kong', 'Singapore',
#        'Thailand', 'Israel', 'Lithuania', 'West Indies', 'Lebanon',
#        'Korea', 'Brazil', 'Canada', 'Iceland'], dtype=object)

# %% [markdown]
# ##### Check null value in dataset

# %%
df.isnull().any()
# Out:
# Invoice        False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# Price          False
# Customer ID     True
# Country        False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %% [markdown]
# ##### removing spaces from some of the descriptions and drop the record that dont have invoice and remove credit transactions

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['Invoice'], inplace=True)
df['Invoice'] = df['Invoice'].astype('str')
df = df[~df['Invoice'].str.contains('C')]
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041          RECORD FRAME 7" SINGLE SIZE        48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %% [markdown]
# ##### we are only looking at sales for France

# %%
basket_France = (df[df['Country'] =="France"] 
          .groupby(['Invoice', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('Invoice')) 
basket_France.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 IVORY ROSE PEG PLACE SETTINGS  \
# Invoice
# 489439                          0.0                               0.0
# 489557                          0.0                               0.0
# 489883                          0.0                               0.0
# 490139                          0.0                               0.0
# 490152                          0.0                               0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# Invoice
# 489439                                   0.0                            0.0
# 489557                                   0.0                            0.0
# 489883                                   0.0                            0.0
# 490139                                   0.0                            0.0
# 490152                                   0.0                            0.0
#
# ...

# %% [markdown]
# ##### There are a lot of zeros in the data but we also need to make sure any positive values are converted to a 1 and anything less than 0 is set to

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
basket_sets = basket_France.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)
basket_sets
# Out:
# /tmp/ipykernel_93411/3499997352.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_sets = basket_France.applymap(encode_units)
# Description  10 COLOUR SPACEBOY PEN  12 IVORY ROSE PEG PLACE SETTINGS  \
# Invoice
# 489439                            0                                 0
# 489557                            0                                 0
# 489883                            0                                 0
# 490139                            0                                 0
# 490152                            0                                 0
# ...                             ...                               ...
# 537693                            0                                 0
# 537897                            0                                 0
# 537967                            0                                 0
# 538008                            0                                 0
# ...

# %% [markdown]
# ##### Generate the rules with their corresponding support, confidence and lift.

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1 , num_itemsets=len(basket_sets))
rules.head()
# Out:
# /home/panha/Desktop/Rupp/Year_4/IDM/apriori_algorithm/env/lib/python3.12/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                        antecedents                      consequents  \
# 0        (CIRCUS PARADE LUNCH BOX)  (PLASTERS IN TIN CIRCUS PARADE)
# 1  (PLASTERS IN TIN CIRCUS PARADE)        (CIRCUS PARADE LUNCH BOX)
# 2             (SPACEBOY LUNCH BOX)        (CIRCUS PARADE LUNCH BOX)
# 3        (CIRCUS PARADE LUNCH BOX)             (SPACEBOY LUNCH BOX)
# 4             (SPACEBOY LUNCH BOX)           (DOLLY GIRL LUNCH BOX)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.116183            0.161826  0.070539    0.607143  3.751832
# 1            0.161826            0.116183  0.070539    0.435897  3.751832
# ...

# %% [markdown]
# ##### Filter the dataframe using standard pandas code, for a large lift (6) and high confidence (.8)

# %%
rules[ (rules['lift'] >= 6) &
      (rules['confidence'] >= 0.8) ]
# Out:
#                         antecedents                    consequents  \
# 5            (DOLLY GIRL LUNCH BOX)           (SPACEBOY LUNCH BOX)
# 34  (SET/6 RED SPOTTY PAPER PLATES)  (SET/6 RED SPOTTY PAPER CUPS)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 5             0.087137             0.13278  0.070539    0.809524  6.096726
# 34            0.120332             0.13278  0.099585    0.827586  6.232759
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 5                1.0  0.058969    4.552905       0.915775  0.472222
# 34               1.0  0.083607    5.029876       0.954403  0.648649
#
#     certainty  kulczynski
# 5    0.780360    0.670387
# 34   0.801188    0.788793
